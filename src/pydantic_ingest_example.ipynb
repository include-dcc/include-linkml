# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 389.3 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 321.9 kB/s eta 0:00:0000:0100:02
# ...
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from include_linkml.include_pydantic import Biospecimen, Participant
from include_linkml.include_pydantic import EnumFamilyType, EnumSex
import pandas as pd
import dataclasses
from random import randint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from include_linkml.include_pydantic import Biospecimen, Participant
#       2 from include_linkml.include_pydantic import EnumFamilyType, EnumSex
# ----> 3 import pandas as pd
#       4 import dataclasses
#       5 from random import randint
#
# ModuleNotFoundError: No module named 'pandas'

# %%
khor = pd.read_excel('data/Khor 2022-08-29 INCLUDE Down Syndrome Cohort Concurrent Conditions.xlsx',
                     sheet_name='Sheet1')

all_harmonized = pd.read_csv('data/all_cohorts_participant_2023-06-08.csv', sep=',')
bri_dsr = all_harmonized[all_harmonized['Study Code']=='BRI-DSR']

# %%
khor
# Out:
#     BRI INCLUDE ID   Patient Type  Age at Enrollment                     Race  \
# 0    INCLUDE000907  Down Syndrome                 53         White, Caucasian
# 1    INCLUDE027754  Down Syndrome                 27  Asian, White, Caucasian
# 2    INCLUDE045500  Down Syndrome                  3         White, Caucasian
# 3    INCLUDE048781  Down Syndrome                  9         White, Caucasian
# 4    INCLUDE050246  Down Syndrome                 10         White, Caucasian
# ..             ...            ...                ...                      ...
# 162  INCLUDE959871  Down Syndrome                 10                    Asian
# 163  INCLUDE959923  Down Syndrome                 13         White, Caucasian
# 164  INCLUDE967357  Down Syndrome                  7         White, Caucasian
# 165  INCLUDE978703  Down Syndrome                  2         White, Caucasian
# 166  INCLUDE998058  Down Syndrome                  4  Black, African American
#
# ...

# %%
khor.head()
# Out:
#   BRI INCLUDE ID   Patient Type  Age at Enrollment                     Race  \
# 0  INCLUDE000907  Down Syndrome                 53         White, Caucasian
# 1  INCLUDE027754  Down Syndrome                 27  Asian, White, Caucasian
# 2  INCLUDE045500  Down Syndrome                  3         White, Caucasian
# 3  INCLUDE048781  Down Syndrome                  9         White, Caucasian
# 4  INCLUDE050246  Down Syndrome                 10         White, Caucasian
#
#    Gender Ethnicity (hispanic/latino y/n) ADHD Autisim  \
# 0    male                              no
# 1  female                              no
# 2    male                              no
# 3    male                              no
# 4    male                              no
#
#   Dravet Syndrome or Lennox Gastaut Ds Catatonia Dysautonomia Dystonia  \
# 0
# 1
# 2
# 3
# 4
#
#   Epilepsy Epileptic Encephalopathy Hirschsprung's Disease Hypotonia STRADA  \
# 0
# 1
# 2
# 3
# 4
#
#   Unverricht-Lundborg Disease
# 0
# 1
# 2
# ...

# %%
khor['Patient Type'].value_counts()
# Out:
# Patient Type
# Down Syndrome    167
# Name: count, dtype: int64

# %%
all_harmonized = pd.read_csv('data/all_cohorts_participant_2023-06-08.csv', sep=',')
bri_dsr = all_harmonized[all_harmonized['Study Code']=='BRI-DSR']

# %%
bri_dsr
# Out:
#     Study Code Participant Global ID Participant External ID Family ID  \
# 417    BRI-DSR         pt-jcfhqfrhjw           INCLUDE000907       NaN
# 418    BRI-DSR         pt-af7a4ra2xz           INCLUDE027754       NaN
# 419    BRI-DSR         pt-mxzdd6qcyq           INCLUDE045500       NaN
# 420    BRI-DSR         pt-ikf4qf4ycm           INCLUDE048781       NaN
# 421    BRI-DSR         pt-fq3kmmb8wi           INCLUDE050246       NaN
# ..         ...                   ...                     ...       ...
# 579    BRI-DSR         pt-8cizmydm8p           INCLUDE959871       NaN
# 580    BRI-DSR         pt-hj8be4jgzm           INCLUDE959923       NaN
# 581    BRI-DSR         pt-yexpqf8w9m           INCLUDE967357       NaN
# 582    BRI-DSR         pt-pr9xiwitiy           INCLUDE978703       NaN
# 583    BRI-DSR         pt-j63mpfyb9f           INCLUDE998058       NaN
#
#       Family Type Father ID Mother ID Sibling ID Other Family Member ID  \
# ...

# %%
bri_dsr['First Patient Engagement Event'].value_counts()
# Out:
# First Patient Engagement Event
# Enrollment    167
# Name: count, dtype: int64

# %%
Participant.__fields__
# Out:
# {'hasStudy': ModelField(name='hasStudy', type=Optional[Study], required=False, default=None),
#  'participantGlobalId': ModelField(name='participantGlobalId', type=Optional[str], required=False, default=None),
#  'participantExternalId': ModelField(name='participantExternalId', type=str, required=True),
#  'familyId': ModelField(name='familyId', type=Optional[str], required=False, default=None),
#  'familyType': ModelField(name='familyType', type=EnumFamilyType, required=True),
#  'fatherId': ModelField(name='fatherId', type=Optional[str], required=False, default=None),
#  'motherId': ModelField(name='motherId', type=Optional[str], required=False, default=None),
#  'siblingId': ModelField(name='siblingId', type=Optional[str], required=False, default=None),
#  'otherFamilyMemberId': ModelField(name='otherFamilyMemberId', type=Optional[str], required=False, default=None),
# ...

# %%
# Out:
# male
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[21], line 4
#       2 if row['Gender']:
#       3     print(row['Gender'])
# ----> 4 p = Participant(
#       5     participantExternalId=row['BRI INCLUDE ID'],
#       6     participantGlobalId=f'pt-{random_with_N_digits(15)}',
#       7     familyType=EnumFamilyType.proband_only
#       8
#       9 )
#      10 print(row['BRI INCLUDE ID'])
#
# File ~/Library/Caches/pypoetry/virtualenvs/linkml-project-template-AkzsagWH-py3.9/lib/python3.9/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 6 validation errors for Participant
# sex
#   field required (type=value_error.missing)
# race
#   field required (type=value_error.missing)
# ethnicity
#   field required (type=value_error.missing)
# downSyndromeStatus
#   field required (type=value_error.missing)
# ...

# %%
EnumSex.male
# Out:
# <EnumSex.male: 'male'>
